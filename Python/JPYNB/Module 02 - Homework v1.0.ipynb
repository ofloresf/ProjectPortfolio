# %% [markdown]
# ### Homework #2

# %% [markdown]
# 1. Round 4.5667 to the nearest hundreth (2 decimals) using a build-in function, round().

# %%
round (4.5667,2)
# Out:
# 4.57

# %% [markdown]
# 2. Convert "657" to an integer data type

# %%
int ("657")
# Out:
# 657

# %% [markdown]
# 3. Write a program to get two numbers from a user. Then, create a 6-digit code that is a series of randomly generated numbers between the two numbers given by the user. Print the 6-digit code so all digits are separated by a dash.

# %%
import random

def generate_random_code():
  # Get two numbers from the user
  print("Enter two numbers to generate a random code:")
  n1 = int(input("First number: "))
  n2 = int(input("Second number: "))

  # Generate a 6-digit random code
  random_code = ""
  for _ in range(6):
    random_code += str(random.randint(n1, n2))

  # Insert dashes between the digits
  random_code = "-".join(random_code)

  return random_code

# Generate and print the random code
random_code = generate_random_code()
print("Random code:", random_code)
# Out:
# Enter two numbers to generate a random code:
# First number: 1
# Second number: 9
# Random code: 8-2-8-8-7-3

# %% [markdown]
# 4. Write a program to remove ALL the white spaces from the following text:
#
#         Hickory, dickory, dock,
#         The mouse ran up the clock.
#         The clock struck one,
#         The mouse ran down,
#         Hickory, dickory, dock

# %%
txt = """Hickory, dickory, dock,
        The mouse ran up the clock.
        The clock struck one,
        The mouse ran down,
        Hickory, dickory, dock  """
new_text = txt.replace(" ", "")

print (new_text)
# Out:
# Hickory,dickory,dock,
# Themouseranuptheclock.
# Theclockstruckone,
# Themouserandown,
# Hickory,dickory,dock

# %% [markdown]
# 5. Write a function to calculate the miles per gallon. Get a miles driven and gallons used from a user and call your function to calculate the miles per gallon.

# %%
#Function to calculate miles per gallon
def miles_per_gallon():
  print("To calculate miles per gallons enter the following information:")
  #Input from user
  print("Enter number of miles:")
  #Miles
  miles = int(input())
  print("Enter number of gallons:")
  #Gallons
  gallons = int(input())

  mpg = (miles / gallons)
  print (mpg)

miles_per_gallon()
# Out:
# To calculate miles per gallons enter the following information:
# Enter number of miles:
# 100
# Enter number of gallons:
# 100
# 1.0

# %% [markdown]
# 6. Enhance the <b>compute()</b> function created during Module 2. Enhance the function to compute a circle's area and circumference where:
#
#  - circle's area = 3.14 X (radius X radius)
#  - circle's circumference = 3.14 X diameter

# %%
#Calculate the circle's area and a circumference

#Function derfinition
def compute():
  #Capture the radius
  print ("Please enter radius: ")
  radius = int(input())
  diameter = radius**2

  # Circle's area
  area = 3.14 * radius **2
  # Circle's circumference
  circumference = 2 * 3.14 * radius

  print ("Circle's area is: ", area)
  print ("Circle's circumference is: ", circumference)

compute()
# Out:
# Please enter radius:
# 100
# Circle's area is:  31400.0
# Circle's circumference is:  628.0

# %% [markdown]
# 7. Write a function called multiply_two() that accepts two parameters. The function should print a message like '15 * 2 = 30'.  Randomly generate two numbers between 1 and 100, then call the function with the two random numbers.

# %%
import random as rand
#multiply_two accept two parameters
def multiply_two():
  #Generate two random numbers between 1 and 100
  rnumber1 = rand.randint(1,100)
  rnumber2 = rand.randint(1,100)
  #Multiply random numbers and print message
  n1 = (rnumber1*rnumber2)
  print (rnumber1,"*",rnumber2,"=",n1)
multiply_two()
# Out:
# 76 * 49 = 3724

# %% [markdown]
# 8. Create a function for a multiplication table.  Get a number from a user and then call you function which produces a multiplication table for that number.
# The output should look something like this:
#
#         Enter a number: 3
#         3 X 1 = 3
#         3 X 2 = 6
#         3 X 3 = 9
#         3 X 4 = 12
#         3 X 5 = 15
#         3 X 6 = 18
#         3 X 7 = 21
#         3 X 8 = 24
#         3 X 9 = 27

# %%
#Multiplication table
def multiplication_table():
  print ("This is a multiplication table")
  #Capture input form the user, number of the multiplication table
  print("Enter a number: ")
  number = int(input())

  x = 0
  for x in range(1,10):
    print(number, "X", x , "=", number*x)

multiplication_table()
# Out:
# This is a multiplication table
# Enter a number:
# 1024
# 1024 X 1 = 1024
# 1024 X 2 = 2048
# 1024 X 3 = 3072
# 1024 X 4 = 4096
# 1024 X 5 = 5120
# 1024 X 6 = 6144
# 1024 X 7 = 7168
# 1024 X 8 = 8192
# 1024 X 9 = 9216
